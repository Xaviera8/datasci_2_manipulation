# %% [markdown]
# <a href="https://colab.research.google.com/github/Xaviera8/Github.Test/blob/main/clean1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
import os

# %% [markdown]
# #Load the Data set

# %%
df = pd.read_csv('healthcare_data_cleaning.csv')
df
# Out:
#       Patient Age  Gender       City of Residence State of Residence  \
# 0              45   Other              West Brian           Kentucky
# 1              25  Female        East Jocelynfurt           Colorado
# 2              51   Other       South Lindseyland               Ohio
# 3              18  Female              Taylorfort       Pennsylvania
# 4              48  Female               Birdmouth            Montana
# ...           ...     ...                     ...                ...
# 22614          18    Male              Davidville               Iowa
# 22615          60    Male           New Davidtown          Tennessee
# 22616          36   Other  North Elizabethborough             Kansas
# 22617          62  Female             Dyerborough         California
# 22618          34   Other       Port Jasmineville               Ohio
#
#       Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0               Yes                Yes      Insurance     Dr. Williams
# 1                No                Yes           Card      Dr. Johnson
# 2               Yes                 No           Cash     Dr. Williams
# 3               Yes            missing           Cash     Dr. Williams
# 4                No                 No      Insurance        Dr. Brown
# ...             ...                ...            ...              ...
# 22614            No                Yes           Cash        Dr. Jones
# 22615            No                 No           Card        Dr. Jones
# 22616           Yes                 No        missing        Dr. Smith
# 22617           Yes                Yes      Insurance     Dr. Williams
# 22618           Yes                Yes      Insurance         Dr. Will
#
#       Disease Diagnosed Medication Prescribed Type of Appointment  \
# 0                   Flu                 Med_E             General
# 1                   Flu                 Med_B          Specialist
# 2              Covid-19                 Med_D             General
# 3                   Flu                 Med_A             General
# 4                  None                 Med_C          Specialist
# ...                 ...                   ...                 ...
# 22614              Cold                 Med_D             missing
# 22615           Allergy                 Med_B          Specialist
# 22616          Covid-19                 Med_C          Specialist
# 22617              Cold                 Med_D             General
# 22618               NaN                   NaN                 NaN
#
#       Average Heart Rate Average BP Height (in cm) Weight (in kg)  \
# 0                     66        111            183             70
# 1                     59    missing            174             58
# 2                     79        119            161             56
# 3                     99        115            171             52
# 4                     93         89            186             87
# ...                  ...        ...            ...            ...
# 22614                 83        111        missing             46
# 22615                 77    missing            167             65
# 22616                 90        122            194             59
# 22617                 88        140            165             77
# 22618                NaN        NaN            NaN            NaN
#
#           Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 0       65.45721578126224                   193                    92
# 1      430.68365678679174                   195               missing
# 2       315.0709305262176               missing                    37
# 3       320.2998987723972                   175                   108
# 4       264.2147372473319                   188                   113
# ...                   ...                   ...                   ...
# 22614   77.24976273054284                   171                   105
# 22615   394.2807412184199                   181                    28
# 22616   452.9121456043795                   192                    83
# 22617  32.073441702642036                   196                    69
# 22618                 NaN                   NaN                   NaN
#
#       Number of Tests Prescription Cost ($)
# 0                   5     15.71751735532889
# 1                   4     80.78647284463952
# 2                   2      64.3921393009105
# 3                   2     8.872859215315316
# 4                   3     77.48311304645532
# ...               ...                   ...
# 22614               4     49.93675629749219
# 22615               7    60.883678995531675
# 22616               5    142.27417673692042
# 22617               4     43.24697708635441
# 22618             NaN                   NaN
#
# [22619 rows x 20 columns]

# %% [markdown]
# #Identify and Handle any missing values in the dataset

# %%
print(df.isnull().sum())
# Out:
# Patient Age              0
# Gender                   0
# City of Residence        0
# State of Residence       0
# Has Insurance            0
# Visited Last Month       0
# Payment Method           0
# Preferred Doctor         0
# Disease Diagnosed        0
# Medication Prescribed    0
# Type of Appointment      0
# Average Heart Rate       0
# Average BP               0
# Height (in cm)           0
# Weight (in kg)           0
# Payment Due ($)          0
# Last Visit (days ago)    0
# Visit Duration (mins)    0
# Number of Tests          0
# Prescription Cost ($)    0
# dtype: int64

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# Patient Age              0
# Gender                   0
# City of Residence        0
# State of Residence       0
# Has Insurance            0
# Visited Last Month       0
# Payment Method           0
# Preferred Doctor         0
# Disease Diagnosed        0
# Medication Prescribed    0
# Type of Appointment      0
# Average Heart Rate       0
# Average BP               0
# Height (in cm)           0
# Weight (in kg)           0
# Payment Due ($)          0
# Last Visit (days ago)    0
# Visit Duration (mins)    0
# Number of Tests          0
# Prescription Cost ($)    0
# dtype: int64

# %% [markdown]
# # Remove any duplicate rows and columns, if they exist

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Clean Colums Names????
